# %%
import pandas as pd
import json

with open("data/newsapi/uk_2_year_oct_update.json", "r") as f:
    oct_data = json.load(f)

# Load in data
with open("data/newsapi/uk_2_year.json", "r") as f:
    source_data = json.load(f) + oct_data

    # Break out into articles and concepts (NER)
    articles_list = []
    concept_list = []
    for item in source_data:
        item_concepts = item.pop("concepts", [])
        for concept in item_concepts:
            concept["article_uri"] = item["uri"]
            concept_list.append(concept)
        articles_list.append(item)

    # Build articles frame and do some basic column setting
    articles = (
        pd.json_normalize(articles_list)
        .rename(columns={"source.title": "source"})
        .assign(date=lambda x: pd.to_datetime(x["date"]))
    ).drop_duplicates(subset=["uri"])

    # Concepts frame is straightforward
    concepts = pd.json_normalize(concept_list).drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pandas as pd
#       2 import json
# ----> 4 with open("data/newsapi/uk_2_year_oct_update.json", "r") as f:
#       5     oct_data = json.load(f)
#       7 # Load in data
#
# File ~/.envs/base/lib/python3.13/site-packages/IPython/core/interactiveshell.py:325, in _modified_open(file, *args, **kwargs)
#     318 if file in {0, 1, 2}:
#     319     raise ValueError(
#     320         f"IPython won't let you open fd={file} by default "
#     321         "as it is likely to crash IPython. If you know what you are doing, "
#     322         "you can use builtins' open."
#     323     )
# --> 325 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/newsapi/uk_2_year_oct_update.json'

# %%
def get_section(url):
    parts = url.split("/")
    return parts[3]


print(articles["url"].apply(get_section).value_counts())

include = ["world", "world-news", "news"]

print(f"Length before filtering {len(articles)}")
articles = articles[articles["url"].apply(get_section).isin(include)]

print(f"Length after filtering: {len(articles)}")
# Out:
# url
# world                                  3004
# news                                   1513
# us-news                                1505
# world-news                             1393
# commentisfree                          1264
# politics                                999
# australia-news                          777
# us                                      260
# business                                210
# opinion                                 144
# media                                   139
# uk-news                                 138
# books                                   113
# film                                    105
# global-development                       91
# tv-and-radio                             90
# music                                    84
# football                                 76
# global-health                            68
# culture                                  66
# technology                               61
# education                                56
# law                                      56
# sport                                    43
# artanddesign                             40
# environment                              36
# global                                   30
# lifeandstyle                             23
# columnists                               23
# society                                  23
# tv                                       20
# stage                                    17
# theobserver                              14
# money                                    14
# travel                                   11
# fashion                                  10
# royal-family                              9
# theatre                                   7
# comedy                                    5
# art                                       5
# science                                   4
# radio                                     4
# games                                     3
# obituaries                                3
# films                                     3
# olympics                                  3
# cricket                                   3
# food                                      2
# cycling                                   2
# basketball                                2
# rugby-union                               2
# golf                                      1
# unicef-australia-survival-to-safety       1
# athletics                                 1
# lifestyle                                 1
# we-are-here-for-humanity                  1
# guardian-us-press-office                  1
# christmas                                 1
# wellness                                  1
# gnm-press-office                          1
# Name: count, dtype: int64
# Length before filtering 12582
# Length after filtering: 5910

# %% [markdown]
# # Filtering
#
# Before undertaking LLM-processing and analysis, we need to filter the articles to ensure appropriate format and relevance.
#
# The objective is to isolate typical-format news articles which have a direct relevance to the conflict.
#
# This is achieved through the following mechanisms:
#
# ## Cropping of very short and long-format articles
# - Short: A typical news piece is around 2,000 characters long, and we see many in the dataset well below that. These are often intro texts to videos or links to external media, and do not represent the majority of news coverage.
# - Long: Some articles are exceedingly long, up to 50,000 characters. Articles of this length pose challenges for LLM-based extraction, and aren't necessarily representative of the overall discourse on Gaza.
#
# I make a conservative crop of the lowest and highest deciles in the batch, removing articles with character lengths that can be considered outliers.
#
# ## Ensuring relevance
# As one of the largest ongoing news stories of the last two years, the conflict in Gaza is mentioned in a wide variety of contexts, often in passing. Articles are extracted from the database on the basis of keyword matching, so even a single mention of Gaza will result in an article being included.
#
# Secondary effects of the conflict, e.g., protests, international diplomacy, are very much considered of relevance, however the dataset contains considerable numbers of articles primarily related to Ukraine, domestic politics in Western nations, broader international politics (e.g. COP28), and even recipes.
#
# I use named-entity recognition, bundled with the data from newsapi to develop a "relevance score" to rank articles on relevance. I then develop a cut-off threshold, based on examination of the data.

# %%
articles["body_length"] = articles["body"].str.len()
print(articles["body_length"].describe().to_markdown())

articles["body_length"].hist(bins=100)
# Out:
# |       |   body_length |
# |:------|--------------:|
# | count |       5910    |
# | mean  |       4567.98 |
# | std   |       3316.27 |
# | min   |        362    |
# | 25%   |       2580.25 |
# | 50%   |       4108.5  |
# | 75%   |       5582.75 |
# | max   |      45948    |
# <Axes: >

# %%
# Get top and bottom deciles
top_decile = articles["body_length"].quantile(0.9)
bottom_decile = articles["body_length"].quantile(0.1)

print(f"Top decile: {top_decile}")
print(f"Bottom decile: {bottom_decile}")

print(f"Total articles before filtering: {len(articles)}")

# Filter by deciles
articles = articles[
    (articles["body_length"] <= top_decile) & (articles["body_length"] >= bottom_decile)
]

print(f"Total articles after filtering: {len(articles)}")

articles["body_length"].hist(bins=100)
# Out:
# Top decile: 7773.600000000002
# Bottom decile: 1190.9
# Total articles before filtering: 5910
# Total articles after filtering: 4728
# <Axes: >

# %% [markdown]
# # Ensuring relevant articles
# We want to make sure that all the articles we're looking at are focussed on Gaza. This will not be the case on the whole dataset, as the data results from a search keyword matches.

# %%
top_concepts = (
    concepts[concepts["article_uri"].isin(articles["uri"].to_list())][
        ["uri", "label.eng"]
    ]
    .value_counts()
    .reset_index()
    .head(25)["label.eng"]
    .values
)

# %%
# I take the top 25 concepts and manually filter to the relevant ones
# Removing those that are not directly related to the Gaza conflict
# This is admittedly somewhat subjective, I considered removing
# "Hostage", "Terrorism", "Antisemitism", and "Genocide" as they could
# Apply in a lot of other contexts, but they are also very relevant to the current
# conflict so I have kept them in.

# The most important ones to remove are things like "United Kingdom", "United States",
# "Donald Trump", "Keir Starmer", etc., where there's a much, much broader news agenda relating
# to these entities that is not related. One of the big problems I had in the first pass was dealing
# with the Trump show.


relevant_concepts = [
    "Gaza Strip",
    "Israel",
    "Hamas",
    "Palestinians",
    "Israel Defense Forces",
    # "United Kingdom",
    "Benjamin Netanyahu",
    "Ceasefire",
    "Terrorism",
    # "Donald Trump",
    "United Nations",
    "Middle East",
    # "Joe Biden",
    "Jews",
    "Hostage",
    "United States",
    "Humanitarian aid",
    "Iran",
    "Airstrike",
    "Prime Minister of Israel",
    "Antisemitism",
    "Egypt",
    "Lebanon",
    # "Australia",
    # "White House",
]
regional_conflict = ["Yemen", "Syria"]

relevant_concepts += regional_conflict

# %%
# Applying the scoring

# Building relevance scoring table
relevance_scoring = (
    concepts[concepts["label.eng"].isin(relevant_concepts)]
    .groupby("article_uri")["score"]
    .sum()
)

# The scores will be biased towards longer articles with more concepts,
# so we normalise by the length of the article

article_lengths = articles.set_index("uri")["body"].str.len()


relevance_scoring = (
    pd.concat([relevance_scoring, article_lengths], axis=1, join="outer")
    .merge(articles.set_index("uri")["title"], left_index=True, right_index=True)
    .rename(columns={"body": "body_length"})
)

# Filling NA with 0, and calculating normalised score
relevance_scoring = relevance_scoring.fillna(0).assign(
    score=lambda x: x["score"] / x["body_length"]
)


# Min-max normalisation to get a 0-1 score
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
relevance_scoring["score"] = scaler.fit_transform(relevance_scoring[["score"]])

# %%
# Cut into 0, 0.02, 0.04, 0.06, 0.08, 0.09, 0.1, 0.1+
relevance_scoring["binned"] = pd.cut(
    relevance_scoring["score"],
    bins=[-0.01, 0.05, 0.06, 0.07, 0.08, 0.09, 0.1, 0.15, 1],
    labels=[
        "0-0.05",
        "0.05-0.06",
        "0.06-0.07",
        "0.07-0.08",
        "0.08-0.09",
        "0.09-0.1",
        "0.1-0.15",
        "0.15+",
    ],
)

# Sample five from each bin
for label, group in relevance_scoring.groupby("binned"):
    print(f"### {label} ###")
    print(
        group.sample(25, random_state=123)[["score", "title"]]
        .sort_values(by="score", ascending=True)
        .to_markdown(index=False)
    )
    print("\n\n")
# Out:
# ### 0-0.05 ###
# |      score | title                                                                                       |
# |-----------:|:--------------------------------------------------------------------------------------------|
# | 0.00297146 | Ed Davey is clueless about his own voters                                                   |
# | 0.00989603 | 'Cliched': Turkish-Germans react as president brings kebab on Istanbul trip                 |
# | 0.0146949  | Former CPS chief says clampdown on protests risks creating 'thought crimes'                 |
# | 0.0149531  | 'A duty to intervene': the former UK government lawyer at centre of pro-Palestine protests  |
# | 0.0188071  | Putin is preparing for nuclear war                                                          |
# | 0.0194376  | Teacher who held placard depicting Sunak and Braverman as coconuts found not guilty         |
# | 0.0194474  | Modi eyes 'super majority' amid fears he will change India's constitution                   |
# | 0.0233256  | Pious Palestine Action activists are nothing like the suffragettes                          |
# | 0.023643   | Sinn Fein's support collapses in local and European elections                               |
# | 0.0263875  | Scotland may never recover from the SNP's venomous nationalism                              |
# | 0.0272646  | Corrections and clarifications                                                              |
# | 0.0278417  | China's foreign minister condemns US imposition of tariffs as 'two-faced'                   |
# | 0.0308011  | Trump expected to visit Britain 'soon' after first call with Starmer since inauguration     |
# | 0.0356377  | Islamophobic incidents in Australia have doubled over the past two years, research suggests |
# | 0.0359345  | German police arrest teenagers planning Islamic State-style terror attack on churches       |
# | 0.0384827  | This is a devastating day for Rishi Sunak                                                   |
# | 0.040578   | George Galloway meets family of men involved in Manchester Airport incident                 |
# | 0.0413041  | 'Into the arms of strangers': child refugees of Nazi Germany remember                       |
# | 0.0415153  | Britain's moral vacuum is leaving us dangerously vulnerable to more riots                   |
# | 0.0416695  | Ian Hislop calls arrest of man holding Private Eye cartoon at Gaza protest 'mind-boggling'  |
# | 0.0416781  | Muslims face 'bleak and dystopian' climate in UK, says head of thinktank                    |
# | 0.0436572  | BBC to expand controversial Verify fact-checking unit                                       |
# | 0.04492    | George Galloway's return is a nightmare for Keir Starmer                                    |
# | 0.0466549  | Disinformation attacks targeted voters, media and LGBTQ+ groups, EU report finds            |
# | 0.0475433  | History weighs like a nightmare on the living if they are ignorant of basic facts           |
#
#
#
# ### 0.05-0.06 ###
# |     score | title                                                                                               |
# |----------:|:----------------------------------------------------------------------------------------------------|
# | 0.0502782 | How Leftists seized control of Britain's doctors' union                                             |
# | 0.0503622 | For the record                                                                                      |
# | 0.0505594 | Russia's Avdiivka offensive is failing, says top Ukrainian officer                                  |
# | 0.0505848 | The Labour Party is in utter, total disarray                                                        |
# | 0.0507254 | Gary Lineker's arrogant BBC interview proves he still just doesn't get it                           |
# | 0.0507701 | Political and religious leaders around the world pay tribute to Pope Francis                        |
# | 0.0517719 | UK government lawyers say Israel is breaking international law, claims top Tory in leaked recording |
# | 0.0521263 | UK Islamophobic assaults surged by 73% in 2024, anti-hate crime charity reports                     |
# | 0.0532693 | Two UK pro-Palestine organisations have bank accounts frozen                                        |
# | 0.0533519 | Home Office to make protesters give more notice of marches                                          |
# | 0.0533786 | Ecstatic crowds flood St Peter's Square to hail election of new pope                                |
# | 0.0535834 | Thursday evening news briefing: Starmer accuses Sunak of 'squatting' in No10                        |
# | 0.0537684 | Macron welcomes Biden for US state visit with Arc de Triomphe ceremony                              |
# | 0.0545289 | University of Toronto gives pro-Palestinian activists 24 hours to end encampment                    |
# | 0.0552664 | Iranians head out to vote in second round of presidential election                                  |
# | 0.0555378 | Children banned from attending protests during school hours                                         |
# | 0.055696  | I was trying to help Ukraine, claims 'Russian spy'                                                  |
# | 0.055696  | Sir Keir should not emulate Hugh Grant                                                              |
# | 0.0570218 | My memories of Henry Kissinger                                                                      |
# | 0.0577525 | Corrections and clarifications                                                                      |
# | 0.0579495 | Farage doesn't want to crush our liberal order, he wants to save it                                 |
# | 0.0588332 | Keir Starmer is a disgrace for wearing military fatigues                                            |
# | 0.059003  | BBC to get tougher scrutiny amid bias concerns                                                      |
# | 0.0597104 | 'People are terrified': Gaza's main hospital overflows with the living and the dead                 |
# | 0.059754  | Labour MP calls Palestine Action arrests 'total disgrace'                                           |
#
#
#
# ### 0.06-0.07 ###
# |     score | title                                                                                                   |
# |----------:|:--------------------------------------------------------------------------------------------------------|
# | 0.0606131 | The domestic pressures shaping India's response to Kashmir attacks                                      |
# | 0.0608028 | Corrections and clarifications                                                                          |
# | 0.060879  | Wednesday evening news briefing: Lineker tweets 'probably broke BBC guidelines'                         |
# | 0.0610916 | Five Labor MPs defy NSW premier and vow to attend pro-Palestine march across Sydney Harbour Bridge      |
# | 0.061469  | Europe's cruel summer: Ursula von der Leyen faces an EU under pressure                                  |
# | 0.0619606 | Israeli Eurovision contender practices song as team boos and shouts pro-Palestinian chants              |
# | 0.0623208 | Hope and scepticism in Ukraine as Zelenskyy says Trump can bring about 'just peace'                     |
# | 0.0776058 | 'Political arrest' of Palestinian academic in Israel is civil liberties threat, say lawyers          |
# | 0.0781567 | Drill, baby, drill: inside the 2 August Guardian Weekly                                              |
# | 0.0783723 | Ministers blundered by turning a new Holocaust memorial into a controversy                           |
# | 0.0783839 | Grant Shapps orders review into plane shortage before 80th D-day anniversary                         |
# | 0.0790461 | 'Jihad' chants can be prosecuted as encouraging terrorism under counter terror legislation           |
# | 0.0791263 | Tuesday evening news briefing: Ed Davey faces growing calls to quit over role in Post Office scandal |
# | 0.0795103 | Doomsday Clock set closer than ever to midnight to stress global catastrophe risks                   |
#
#
#
# ### 0.08-0.09 ###
# |     score | title                                                                                            |
# |----------:|:-------------------------------------------------------------------------------------------------|
# | 0.0803913 | Watch: Pro-Palestine activists storm Israeli arms company's UK HQ                                |
# | 0.080431  | Are you 'far-Right'? Take our quiz!                                                              |
# | 0.0806826 | Pro-Palestine protest camps spread to 40 campuses across US                                      |
# | 0.0812757 | Tribalism is tearing Britain apart. It cannot go on                                              |
# | 0.0824799 | Palestine Action ban coupled with Online Safety Act 'are threat to public debate'                |
# | 0.0827182 | If you thought Mick Lynch enjoyed bringing Britain to a halt, you should see who may replace him |
# | 0.0830782 | Houthis claim cargo ship is at risk of sinking after Red Sea attack                              |
# | 0.0842065 | Friday evening news briefing: Slaying dragons is a worthwhile price to pay, says Prince Harry    |
# | 0.084818  | UK upheld some arms export licences to Israel to reassure US                                     |
# | 0.0850482 | Corrections and clarifications                                                                   |
# | 0.0852735 | Civil Service guidance directed officials to website that likened homosexuality to 'a scourge'   |
# | 0.0855936 | Musicians and artists boycott UK cultural events over Israel ties                                |
# | 0.0855936 | 'It's a very big secret': meet the ultra-orthodox Jews shunning their families to fight in Gaza  |
# | 0.0857457 | How Allison Pearson's tweet sparked a year-long police investigation                             |
# | 0.085764  | Terror case against Kneecap rapper thrown out after mistake by Hermer                            |
# | 0.0861522 | Police protect Durham University students holding Gaza debate                                    |
# | 0.08661   | Pro-Palestine group targets Jewish-owned business alleging links to Israeli weapons firm         |
# | 0.0868591 | Palestine Action's proscription may end up as a propaganda coup for Israel haters                |
# | 0.0870873 | Israeli public figures accuse judiciary of ignoring incitement to genocide in Gaza               |
# | 0.0877227 | Germany summons Chinese envoy over laser-targeting of surveillance plane                         |
# | 0.0878572 | The Biden house of cards is collapsing                                                           |
# | 0.088267  | Labour's Zarah Sultana takes Cameron to task over UK arms sales to Israel                        |
# | 0.088321  | US to station nuclear weapons in UK to counter threat from Russia                                |
# | 0.0890374 | What is the Red Sea crisis - and what does it mean for global trade?                             |
# | 0.0894955 | Guy Pearce and Annie Lennox join call to end 'normalised horror' for children in Gaza            |
#
#
#
# ### 0.09-0.1 ###
# |     score | title                                                                                                               |
# |----------:|:--------------------------------------------------------------------------------------------------------------------|
# | 0.0900544 | New Zealand Greens MP Golriz Ghahraman steps aside from portfolios after shoplifting claim                          |
# | 0.0902896 | The real reason liberals attack Israel                                                                              |
# | 0.0905544 | Shut down the asylum system until we figure out what the hell is going on                                           |
# | 0.091747  | Friends of woman killed in Israeli kibbutz pledge to rebuild settlement                                             |
# | 0.0919866 | Hezbollah's terrible blunder that ended with audacious pager attack                                                 |
# | 0.092052  | BBC shelves Gaza medics documentary over impartiality concerns                                                      |
# | 0.0932552 | Islamic State is primed to be thorn in the side of incoming Trump administration                                    |
# | 0.0947405 | Israeli jets disrupt speech of Hezbollah leader as he vows revenge for blasts                                       |
# | 0.0953081 | LGBT Jewish charity forced to pull out of Pride over safety fears                                                   |
# | 0.0955531 | Calling Gaza protesters extremist risks dividing UK, says government's cohesion adviser                             |
# | 0.095975  | Police may be trying to criminalise all Palestine protests. But we will march on | Letter                           |
# | 0.0960684 | The West is preparing for a future without America                                                                  |
# | 0.0968913 | Pictured: Russians make Mad Max modifications to their motorbikes                                                   |
# | 0.0969718 | BBC's Annie Mac backs Kneecap in freedom of expression row                                                          |
# | 0.0970322 | The SNP's foreign policy play-acting is becoming an Orwellian farce                                                 |
# | 0.0973111 | Humza Yousaf says inviting Erdogan to Scotland not linked to Turkey helping in-laws flee Gaza                       |
# | 0.0975487 | 'Hot mic' hot mess: gaffes made by global leaders when they think no one is listening                               |
# | 0.0978621 | How the idea for a Trump Tower in Damascus was born                                                                 |
# | 0.0978677 | Violent Israeli settlers under UK sanctions join illegal West Bank outpost                                          |
# | 0.0978857 | Not welcome: inside the 29 August Guardian Weekly                                                                   |
# | 0.097998  | Severe malnutrition among under-5s in Gaza City has tripled in two weeks, charity says                              |
# | 0.0983179 | Impact of Hezbollah assassinations may take months to emerge                                                        |
# | 0.0984668 | The Crunch: The shrinking space to exist in Gaza; redrawing the world map; and are there any safe seats on a plane? |
# | 0.0993698 | As wars rage, it's vital to watch China in the Taiwan Strait. The US Navy gets this                                 |
# | 0.0998909 | Britain has just cemented its role as Europe's leader in the battle against tyrants                                 |
#
#
#
# ### 0.1-0.15 ###
# |    score | title                                                                                                           |
# |---------:|:----------------------------------------------------------------------------------------------------------------|
# | 0.102175 | Three people killed and 13 injured in Jerusalem shooting                                                        |
# | 0.103364 | 'So many similarities': Rachel Corrie's parents call for inquiry into death of Ayşenur Ezgi Eygi                |
# | 0.104299 | Russian commanders face prosecution for starving Mariupol in first-of-its-kind case                             |
# | 0.105831 | 'This was her haven': son returns to Israel kibbutz where his mother was abducted                               |
# | 0.106718 | House approves $61bn aid for Ukraine - what we know so far, and what happens next                               |
# | 0.107362 | Trump's UN speech makes it clear: the world can no longer look to the US for strong leadership                  |
# | 0.108253 | Hungary invites Netanyahu to visit as world leaders split over ICC arrest warrant                               |
# | 0.112436 | Microsoft blocks Israel's use of its technology in mass surveillance of Palestinians                            |
# | 0.11531  | Attacks across Europe put Islamist extremism back in spotlight                                                  |
# | 0.11646  | Diplomacy and drones: how Israel's attack on Iran unfolded                                                      |
# | 0.442565 | UK surveillance aircraft to search for Hamas hostage sites in Israel and Gaza                             |
# | 0.449953 | UK, US and allies offer Israel 'steadfast support' in joint statement                                     |
# | 0.476805 | Netanyahu says Israel paying 'heavy price' for war as deaths mount                                        |
# | 0.567041 | Israel says it will allow 'basic' amounts of food into Gaza after 10-week blockade - Israel-Gaza war live |
# | 0.56833  | Israel-Hamas war latest: Israeli tanks capture Rafah border crossing                                      |
# /tmp/ipykernel_21461/3335913764.py:18: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for label, group in relevance_scoring.groupby("binned"):

# %% [markdown]
# Looking at the articles, we can see that a cut-off of 0.093 seems to be reasonable, as we start getting relevant articles from that point onwards. Below that, the articles are mostly not relevant.
#
# It also neatly matches a change in the distribution.

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(14, 4))
relevance_scoring["score"].hist(bins=100, ax=ax)

ax.axvline(x=0.07, color="red", linestyle="--")

# %%
articles["relevance_score"] = articles["uri"].map(relevance_scoring["score"])

print(f"Length before filtering: {len(articles)}")
articles = articles[articles.relevance_score >= 0.07]
print(f"Length after filtering: {len(articles)}")
# Out:
# Length before filtering: 4728
# Length after filtering: 4280

# %% [markdown]
# # Saving

# %%
# Write back raw filtered data

with open("data/newsapi/uk_2_year_filtered.json", "w") as f:
    filtered_articles = [i for i in source_data if i["uri"] in articles["uri"].values]
    json.dump(filtered_articles, f, ensure_ascii=False, indent=4)

# %%
# Preparing prompt for quote extraction
from prep_for_llm import create_request

PROMPT = """
Extract quotes from the following article and return as structured JSON using the following fields.
    name: The full name of the person being quoted
            - If the person is a spokesperson for an organisation, leave blank and set organisation to the organisation they represent.
            - If the person is a spokesperson for a public figure, set the name as that of the public figure and set organisation to the organisation they represent.
            - Do not use a person's first or last name only, unless they are only referred to that way in the article.
            - Even then, if they are famous (e.g., "Donald Trump", "Joe Biden"), always use their full name.
    organisation: The organisation represented by the speaker, 
                  - Use the full name of the organisation rather than just the acronym.
    role: The speaker's position within that organisation, if given in the article.
    nationality: The nationality of the speaker, if known, as a 3-letter country code e.g. USA, GBR, ISR, PLE.
                    - Return an empty string if unknown.
                    - If the quote is from an organisation, infer nationality where possible:
                        - This may be from the name (e.g., "Scotland Yard" -> "GBR")
                        - Or context, for example a political party or health ministry will be from the country it is based in.
    quote: The text of the quote, if the quote breaks across the sentence, merge it into on single quote,
    message: A summary of the quote, written so that it can be understood out of context. 
             Do not include the speaker in the message, reproduce as if it was being spoken directly.
             Ensure that the message can be understood independently of the article, and that all subjects of the message are clear. 
                For example:
                    - do just not say "I agree with the government's decision", say "I agree with the German government's decision to increase funding for healthcare".
                    - do not just say "The report is very important", say "The report, published by Greenpeace, which is about climate change, is very important".

There may be several or no quotes in the article, please ensure that you return all quotes. One speaker may have several quotes.

Include direct quotes only, do not include paraphrased quotes.

Here is the article:
"""

requests = []
for record in filtered_articles:
    requests.append(create_request(record, prompt=PROMPT))

# Write as jsonl
with open("data/newsapi/uk_2_year_filtered_for_llm.jsonl", "w") as f:
    for req in requests:
        f.write(json.dumps(req) + "\n")
